# %% [markdown]
# # Interactive Regression!
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Lesson Plan!
#
# #### 15 Minutes
# 1. Brainstorm what we are going to measure and compare! What will be our features and what is our objective?
#
# 2. **Do we care about length? Height? Airtime?**
#
# 3. Identify a plane thrower
#
# 4. Create a score board

# %% [markdown]
# #### 30 Minutes
# Build planes and gather data!
#
# #### 15 Minutes
# Recap

# %% [markdown]
# ## Inspiration
#
# ### The Dart
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The Steath
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The Bumble
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The Hunter
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The Bullnose
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### References
#
# https://cdn3.vectorstock.com/i/1000x1000/08/72/paper-plane-flat-symbols-set-paper-origami-vector-8430872.jpg
#
# https://www.diynetwork.com/made-and-remade/learn-it/5-basic-paper-airplanes
